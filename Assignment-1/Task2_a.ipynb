# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import math 
import numpy as np
import random
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %%
def f(x):
    return (-2 * math.cos(x) / math.pi) + (x / math.pi) - (2 * math.cos(3 * x) / (3 * math.pi))

# %%
def generate_data_with_gaussian_noise(scaling_factor, total_number_of_data_points):
    dataset = []
    while total_number_of_data_points > 0:
        x = round(random.uniform(-10, 10), 2)
        noise = scaling_factor * np.random.normal(0, 1)
        y = f(x) + noise
        dataset.append((x,y))
        total_number_of_data_points-=1
    return dataset

# %%
def find_error(Y_true, Y_pred):
    n = len(Y_true)
    mean_square_error = 0
    for i in range (n):
       mean_square_error = mean_square_error + (Y_true[i] - Y_pred[i]) ** 2
    mean_square_error = mean_square_error / n
    return mean_square_error

# %%
def polynomial_regression_sklearn(X, Y, degree):

# %%
def polynomial_regressor_gaus(X, Y, degree):
    coefficients = polynomial_regression_sklearn(X, Y, degree)
    Y_pred = []
    n = len(X)
    for i in range (n):
        y_pred = 0
        for deg in range (degree+1):
            y_pred = y_pred + coefficients[deg] * pow(X[i], deg)
        Y_pred.append(y_pred)
    return Y_pred

# %%
random.seed(65)
total_number_of_data_points = 50
scaling_factor = 0.1
dataset50 = generate_data_with_gaussian_noise(scaling_factor, total_number_of_data_points)
X = [dataset_instance[0] for dataset_instance in dataset50]
Y = [dataset_instance[1] for dataset_instance in dataset50]

# %%
print(dataset50)
# Out:
# [(-1.71, -0.3899771430571872), (-4.25, -1.1513134329176935), (6.89, 1.4275857582574556), (-1.12, -0.4966493135824935), (0.57, -0.3910564644421733), (1.03, 0.30502141354980256), (-3.22, -0.0405876312567065), (2.79, 1.5533033044565274), (8.0, 2.5434060723151477), (-8.56, -2.4919098921922536), (1.22, 0.36340858780622126), (-4.72, -1.5868601510093252), (3.11, 2.0176263691866216), (2.47, 1.2973926542487173), (-9.09, -2.1815114079604587), (-7.74, -2.5436594131293764), (0.57, -0.2640256749840666), (7.17, 2.1584274025697643), (5.95, 1.1635581862491058), (6.48, 1.0616830231422834), (-7.26, -2.4471874027586282), (-2.99, -0.2355294789816868), (1.54, 0.4661162481998652), (-2.67, -0.37009057769924414), (-5.39, -1.9600487477865611), (8.44, 2.7582001074198805), (2.7, 1.5222015636712185), (-2.04, -0.607424728898965), (-0.48, -0.805939291725347), (3.99, 1.490524861616789), (5.19, 1.6297323526452747), (5.59, 1.4554876941805976), (-3.31, -0.22905878504684865), (9.35, 3.8584580681181233), (5.26, 1.65487
# ...

# %%
def plotGraph(X, Y, title):
    fig, ax = plt.subplots()
    ax.set_xlim(0, 20)
    ax.set_ylim(0, 0.5)
    plt.plot(X, Y, marker='o', linestyle='-', color='b', label='Data Points')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title(title)
    plt.legend()  
    plt.show()

# %%
def scatter_plot(X, Y, title):
    fig, ax = plt.subplots()
    ax.set_xlim(-11, 11)
    ax.set_ylim(-10, 10)
    plt.scatter(X, Y, marker='o', color='blue')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title(title)
    plt.legend()  
    plt.show()

# %%
X_cont = []
Y_cont = []
for x in np.arange(-10.0, 10.1, 0.01):
    X_cont.append(x)
    Y_cont.append(f(x))
fig, ax = plt.subplots()
ax.set_xlim(-11, 11)
ax.set_ylim(-5, 5)
plt.scatter(X_cont, Y_cont, marker='o',  s=2, color='yellow')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Original function')
plt.legend()  
plt.show()

fig, ax = plt.subplots()
ax.set_xlim(-11, 11)
ax.set_ylim(-5, 5)
plt.scatter(X, Y, marker='o',  s=2, color='blue')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Dataset Points')
plt.legend()  
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for i in range (1, 21):
    coefficients = polynomial_regression_sklearn(X, Y, i)
    X_degree_i = []
    Y_degree_i = []
    for x in np.arange(-10.0, 10.1, 0.01):
        y_temp=0
        X_degree_i.append(x)
        for deg in range(0, i+1):
            y_temp = y_temp + coefficients[deg] * pow (x, deg)
        Y_degree_i.append(y_temp)
    fig, ax = plt.subplots()
    ax.set_xlim(-11, 11)
    ax.set_ylim(-5, 5)
    plt.scatter(X_cont, Y_cont, marker='o',  s=2, color='yellow', label = 'f(X)')
    plt.scatter(X, Y, marker='o',  s=2, color='blue', 'Dataset Points')
    plt.scatter(X_degree_i, Y_degree_i, marker='o',  s=2, color='green', label = 'h(x)')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('')
    plt.legend()  
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
empirical_errors = []
m = []
for i in range (1,21):
    Y_pred = polynomial_regressor_gaus(X, Y, i)
    empirical_error = find_error(Y, Y_pred)
    m.append(i)
    empirical_errors.append(empirical_error)

title = 'empirical error vs m'
fig, ax = plt.subplots()
ax.set_xlim(0, 21)
ax.set_ylim(0, 0.4)
plt.plot(m, empirical_errors, marker='o', linestyle='-', color='b', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(title)
plt.legend()  
plt.show()

# %%
total_number_of_data_points = 500
scaling_factor = 0.1
dataset500 = generate_data_with_gaussian_noise(scaling_factor, total_number_of_data_points)
X500 = [dataset_instance[0] for dataset_instance in dataset500]
Y500 = [dataset_instance[1] for dataset_instance in dataset500]

# %%
for i in range (1, 21):
    coefficients = polynomial_regression_sklearn(X500, Y500, i)
    X_degree_i = []
    Y_degree_i = []
    for x in np.arange(-10.0, 10.1, 0.01):
        y_temp=0
        X_degree_i.append(x)
        for deg in range(0, i+1):
            y_temp = y_temp + coefficients[deg] * pow (x, deg)
        Y_degree_i.append(y_temp)
    fig, ax = plt.subplots()
    ax.set_xlim(-11, 11)
    ax.set_ylim(-5, 5)
    plt.scatter(X_cont, Y_cont, marker='o',  s=2, color='yellow')
    plt.scatter(X, Y, marker='o',  s=2, color='blue')
    plt.scatter(X_degree_i, Y_degree_i, marker='o',  s=2, color='green')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Original function')
    plt.legend()  
    plt.show()

# %%
empirical_errors = []
m = []
for i in range (1,21):
    Y_pred500 = polynomial_regressor_gaus(X500, Y500, i)
    empirical_error = find_error(Y500, Y_pred500)
    m.append(i)
    empirical_errors.append(empirical_error)

title = 'empirical error vs m'
fig, ax = plt.subplots()
ax.set_xlim(0, 21)
ax.set_ylim(0, 0.4)
plt.plot(m, empirical_errors, marker='o', linestyle='-', color='b', label='Data Points')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(title)
plt.legend()  
plt.show()

# %%
def sample_dataset(X, Y, no_of_samples):
    dataset_size = len(X)
    sampled_dataset = []
    while no_of_samples > 0:
        idx = random.randint(0, dataset_size - 1)
        sampled_dataset.append((X[idx], Y[idx]))
        no_of_samples-=1
    return sampled_dataset

# %%
def calculate_mean(Y_pred):
    return list(np.array(Y_pred).mean(axis=0))

# %%
def calculate_bias(Y, Y_pred_mean):
    return np.mean((Y - Y_pred_mean)**2)

# %%
def calculate_variance(Y_pred):
    return np.mean(np.var(Y_pred, axis=0))

# %%
biases = []
variances = []
m = []
print(X)
print(Y)
for i in range (1, 21):
    m.append(i)
    poly = PolynomialFeatures(degree = i, include_bias=False)
    X = np.array(X)
    Y = np.array(Y)
    X = X.reshape(-1, 1)
    X_poly = poly.fit_transform(X)
    no_of_sample = 200
    Y_pred = []
    Y_pred_mean = []
    for j in range (1, 101):
        sampled_dataset = sample_dataset(X, Y, no_of_sample)
        X_j = [dataset_instance[0] for dataset_instance in sampled_dataset]
        Y_j = [dataset_instance[1] for dataset_instance in sampled_dataset]
        X_j = np.array(X_j)
        Y_j = np.array(Y_j)
        X_j = X_j.reshape(-1, 1)
        poly = PolynomialFeatures(degree = i, include_bias=False)
        X_poly_j = poly.fit_transform(X_j)
        model = LinearRegression()
        model.fit(X_poly_j, Y_j)
        y_pred = model.predict(X_poly)
        Y_pred.append(y_pred)
    Y_pred_mean = calculate_mean(Y_pred)
    bias = calculate_bias(Y, Y_pred_mean)
    variance = calculate_variance(Y_pred)
    biases.append(bias)
    variances.append(variance)
print(biases)
print(variances)
title = 'bias and variances vs m'
fig, ax = plt.subplots()
ax.set_xlim(0, 21)
ax.set_ylim(0, 0.5)
plt.plot(m, biases, marker='o', linestyle='-', color='yellow', label='bias')
plt.plot(m, variances, marker='o', linestyle='-', color='green', label='variance')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(title)
plt.legend()  
plt.show()
# Out:
# [-1.71, -4.25, 6.89, -1.12, 0.57, 1.03, -3.22, 2.79, 8.0, -8.56, 1.22, -4.72, 3.11, 2.47, -9.09, -7.74, 0.57, 7.17, 5.95, 6.48, -7.26, -2.99, 1.54, -2.67, -5.39, 8.44, 2.7, -2.04, -0.48, 3.99, 5.19, 5.59, -3.31, 9.35, 5.26, -4.59, -6.56, -1.4, -4.79, 7.55, -9.81, 6.36, -6.76, 6.24, -1.35, -7.36, 9.71, -1.62, 9.57, -3.55]
# ...

# %%
#for degree 14
degree = 14
biases = []
variances = []
N = []
for n in range (50, 1001, 50):
    N.append(n)
    dataset_n = generate_data_with_gaussian_noise(scaling_factor, n)
    X_n = [dataset_instance[0] for dataset_instance in dataset_n]
    Y_n = [dataset_instance[1] for dataset_instance in dataset_n]
    poly = PolynomialFeatures(degree = degree, include_bias=False)
    X_n = np.array(X_n)
    Y_n = np.array(Y_n)
    X_n = X_n.reshape(-1, 1)
    X_poly_n = poly.fit_transform(X_n)
    no_of_sample = 4*n
    Y_pred = []
    Y_pred_mean = []
    for j in range (1, 101):
        sampled_dataset = sample_dataset(X_n, Y_n, no_of_sample)
        X_j = [dataset_instance[0] for dataset_instance in sampled_dataset]
        Y_j = [dataset_instance[1] for dataset_instance in sampled_dataset]
        X_j = np.array(X_j)
        Y_j = np.array(Y_j)
        X_j = X_j.reshape(-1, 1)
        poly = PolynomialFeatures(degree = degree, include_bias=False)
        X_poly_j = poly.fit_transform(X_j)
        model = LinearRegression()
        model.fit(X_poly_j, Y_j)
        y_pred = model.predict(X_poly_n)
        Y_pred.append(y_pred)
    Y_pred_mean = calculate_mean(Y_pred)
    bias = calculate_bias(Y_n, Y_pred_mean)
    variance = calculate_variance(Y_pred)
    biases.append(bias)
    variances.append(variance)
print(biases)
print(variances)
title = 'bias and variances vs m'
fig, ax = plt.subplots()
ax.set_xlim(0, 1001)
ax.set_ylim(0, 0.05)
plt.plot(N, biases, marker='o', linestyle='-', color='yellow', label='bias')
plt.plot(N, variances, marker='o', linestyle='-', color='green', label='variance')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(title)
plt.legend()  
plt.show()

title = 'variances vs m'
fig, ax = plt.subplots()
ax.set_xlim(0, 1001)
ax.set_ylim(0, 0.002)
plt.plot(N, variances, marker='o', linestyle='-', color='green', label='variance')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(title)
plt.legend()  
plt.show()
# Out:
# [0.02224492633986298, 0.030868810404784494, 0.023168315978233826, 0.02828478676990276, 0.025310895315398697, 0.029323986060826132, 0.028401870571865443, 0.028239163613476715, 0.029557185706193926, 0.029519158623046795, 0.028873719492119348, 0.028883723816888807, 0.02973007841928893, 0.030518061902693166, 0.027402952468637012, 0.029996709641447707, 0.029025661382964217, 0.030321978476640418, 0.02927712436133264, 0.02844898444732207]
# [0.0018718821953437562, 0.0009479089745453771, 0.0005392136456407342, 0.0005240006246415573, 0.0003375624384383471, 0.00031798641701300266, 0.00027811410740485225, 0.00022493054579053124, 0.0002313514050077642, 0.00020069454776686912, 0.00016937928980556016, 0.00015690707784768072, 0.00015520534728348233, 0.00015895388961936185, 0.00011772782244358304, 0.00011531433752348075, 0.00011907191882280694, 0.00011246533622317059, 0.00010855424529014623, 9.424461841182576e-05]
